# %%
import ollama

response = ollama.chat(
    model='gemma3:12b',
    messages=[{'role': 'user', 'content': 'เขียนโค้ด Python ทำ linear regression ด้วย scikit-learn'}]
)

print(response['message']['content'])
# Out:
# ```python
# import numpy as np
# from sklearn.linear_model import LinearRegression
# import matplotlib.pyplot as plt
#
# # สร้างข้อมูลตัวอย่าง (Example data)
# # X คือตัวแปรอิสระ (independent variable)
# # y คือตัวแปรตาม (dependent variable)
# X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Reshape เป็น column vector
# y = np.array([2, 4, 5, 4, 3])
#
# # สร้างโมเดล Linear Regression
# model = LinearRegression()
#
# # ฝึกฝนโมเดล (Fit the model)
# model.fit(X, y)
#
# # ทำนายค่า (Make predictions)
# y_pred = model.predict(X)
#
# # แสดงผลลัพธ์
# print("ค่าสัมประสิทธิ์ (Coefficient):", model.coef_)
# print("ค่าตัดแกน (Intercept):", model.intercept_)
#
# # สร้างกราฟ
# plt.scatter(X, y, label="Data")
# plt.plot(X, y_pred, color='red', label="Regression Line")
# plt.xlabel("X")
# plt.ylabel("y")
# plt.title("Linear Regression with Scikit-learn")
# plt.legend()
# plt.show()
# ```
#
# **คำอธิบายโค้ด:**
#
# 1. **`import numpy as np`**:  นำเข้าไลบรารี NumPy สำหรับการคำนวณทางคณิตศาสตร์
# ...
